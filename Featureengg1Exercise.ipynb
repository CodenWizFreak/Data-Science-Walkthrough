# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/dasgu/Desktop/MyImp/Code/aiml/AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df1=df[['id','name','price','minimum_nights']]
df1.head()
# Out:
#      id                                              name  price  \
# 0  2539                Clean & quiet apt home by the park    149
# 1  2595                             Skylit Midtown Castle    225
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !    150
# 3  3831                   Cozy Entire Floor of Brownstone     89
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     80
#
#    minimum_nights
# 0               1
# 1               1
# 2               3
# 3               1
# 4              10

# %%
df1['price_per_night']=df1['price']/df1['minimum_nights']
df1.head()
# Out:
# C:\Users\dasgu\AppData\Local\Temp\ipykernel_19420\1908803799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['price_per_night']=df1['price']/df1['minimum_nights']
#      id                                              name  price  \
# 0  2539                Clean & quiet apt home by the park    149
# 1  2595                             Skylit Midtown Castle    225
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !    150
# 3  3831                   Cozy Entire Floor of Brownstone     89
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     80
#
#    minimum_nights  price_per_night
# 0               1            149.0
# 1               1            225.0
# 2               3             50.0
# ...

# %%
min_threshold,max_threshold=df1['price_per_night'].quantile([0.05,0.95])
min_threshold,max_threshold
# Out:
# (3.3333333333333335, 200.0)

# %%
df1.describe()
# Out:
#                  id         price  minimum_nights  price_per_night
# count  4.889500e+04  48895.000000    48895.000000     48895.000000
# mean   1.901714e+07    152.720687        7.029962        70.174247
# std    1.098311e+07    240.154170       20.510550       157.620388
# min    2.539000e+03      0.000000        1.000000         0.000000
# 25%    9.471945e+06     69.000000        1.000000        20.000000
# 50%    1.967728e+07    106.000000        3.000000        44.500000
# 75%    2.915218e+07    175.000000        5.000000        81.500000
# max    3.648724e+07  10000.000000     1250.000000      8000.000000

# %%
df1.shape
# Out:
# (48895, 5)

# %%
df2=df1[(df1['price_per_night']<max_threshold)&(df1['price_per_night']>min_threshold)]
df2
# Out:
#              id                                               name  price  \
# 0          2539                 Clean & quiet apt home by the park    149
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !    150
# 3          3831                    Cozy Entire Floor of Brownstone     89
# 4          5022   Entire Apt: Spacious Studio/Loft by central park     80
# 5          5099          Large Cozy 1 BR Apartment In Midtown East    200
# ...         ...                                                ...    ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse     70
# 48891  36485057      Affordable room in Bushwick/East Williamsburg     40
# 48892  36485431            Sunny Studio at Historical Neighborhood    115
# 48893  36485609               43rd St. Time Square-cozy single bed     55
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen     90
#
#        minimum_nights  price_per_night
# 0                   1       149.000000
# ...

# %%
df2.describe()
# Out:
#                  id         price  minimum_nights  price_per_night
# count  4.388900e+04  43889.000000    43889.000000     43889.000000
# mean   1.887411e+07    134.990818        5.056688        54.459217
# std    1.089897e+07    143.569910        8.165591        42.177076
# min    2.539000e+03     10.000000        1.000000         3.354839
# 25%    9.464543e+06     70.000000        2.000000        22.000000
# 50%    1.947506e+07    105.000000        2.000000        44.500000
# 75%    2.880134e+07    165.000000        4.000000        75.000000
# max    3.648724e+07  10000.000000      365.000000       199.750000
